# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeslina11/Jeslina-Kondo-221011078/blob/main/Tugas%20akhir%20ALIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Jeslin.png'
img = cv2.imread(img_path)
print(img.shape)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (1600, 1200, 3)
# [[[ 39  30  21]
#   [ 44  35  26]
#   [ 38  25  17]
#   ...
#   [141 136 133]
#   [141 136 133]
#   [141 136 133]]
#
#  [[ 40  31  22]
#   [ 45  36  27]
#   [ 39  26  18]
#   ...
#   [141 136 133]
#   [141 136 133]
#   [141 136 133]]
#
#  [[ 41  32  23]
#   [ 44  35  26]
#   [ 40  27  19]
#   ...
#   [141 136 133]
#   [141 136 133]
#   [141 136 133]]
#
#  ...
#
#  [[ 30  20   8]
#   [ 27  17   5]
#   [ 23  13   1]
#   ...
#   [ 63  50  34]
#   [ 64  51  35]
#   [ 64  51  35]]
#
#  [[ 34  24  12]
#   [ 31  21   9]
#   [ 29  19   7]
#   ...
#   [ 63  50  34]
#   [ 64  51  35]
#   [ 64  51  35]]
#
#  [[ 40  30  18]
#   [ 38  28  16]
#   [ 36  26  14]
#   ...
#   [ 63  50  34]
#   [ 64  51  35]
#   [ 64  51  35]]]

# %%
fix_img[:] = np.max(fix_img, axis =-1, keepdims =1)/2 + np.min(fix_img, axis =-1, keepdims =-1)/2

print(np.array, fix_img[:])
plt.axis('off') ##manghilangkan garis
plt.imshow(fix_img[:])
plt.savefig('metode lightness.jpg', bbox_inches='tight')
# Out:
# <built-in function array> [[[ 30  30  30]
#   [ 35  35  35]
#   [ 27  27  27]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  [[ 31  31  31]
#   [ 36  36  36]
#   [ 28  28  28]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  [[ 32  32  32]
#   [ 35  35  35]
#   [ 29  29  29]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  ...
#
#  [[ 19  19  19]
#   [ 16  16  16]
#   [ 12  12  12]
#   ...
#   [ 48  48  48]
#   [ 49  49  49]
#   [ 49  49  49]]
#
#  [[ 23  23  23]
#   [ 20  20  20]
#   [ 18  18  18]
#   ...
#   [ 48  48  48]
#   [ 49  49  49]
#   [ 49  49  49]]
#
#  [[ 29  29  29]
#   [ 27  27  27]
#   [ 25  25  25]
#   ...
#   [ 48  48  48]
#   [ 49  49  49]
#   [ 49  49  49]]]

# %%
lumi_img=(0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)

plt.axis('off')
plt.imshow(lumi_img, cmap ='gray')
plt.savefig('Metode Average.jpg', bbox_inches='tight')
# Out:
# [[ 30.  35.  27. ... 137. 137. 137.]
#  [ 31.  36.  28. ... 137. 137. 137.]
#  [ 32.  35.  29. ... 137. 137. 137.]
#  ...
#  [ 19.  16.  12. ...  48.  49.  49.]
#  [ 23.  20.  18. ...  48.  49.  49.]
#  [ 29.  27.  25. ...  48.  49.  49.]]

# %%
wavr_img=(0.2126*R) + (0.7152*G) + (0.0722*B)
print(wavr_img)

plt.axis('off')
plt.imshow(wavr_img, cmap ='gray')
plt.savefig('Metode Average.jpg', bbox_inches='tight')
# Out:
# [[ 30.  35.  27. ... 137. 137. 137.]
#  [ 31.  36.  28. ... 137. 137. 137.]
#  [ 32.  35.  29. ... 137. 137. 137.]
#  ...
#  [ 19.  16.  12. ...  48.  49.  49.]
#  [ 23.  20.  18. ...  48.  49.  49.]
#  [ 29.  27.  25. ...  48.  49.  49.]]
